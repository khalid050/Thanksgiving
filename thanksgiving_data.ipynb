# %%
import numpy as py
import pandas as pd

# %%
data = pd.read_csv("thanksgiving-2015-poll-data.csv" , encoding="Latin-1")
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['RespondentID', 'Do you celebrate Thanksgiving?',
#        'What is typically the main dish at your Thanksgiving dinner?',
#        'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        'How is the main dish typically cooked?',
#        'How is the main dish typically cooked? - Other (please specify)',
#        'What kind of stuffing/dressing do you typically have?',
#        'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        'What type of cranberry saucedo you typically have?',
#        'What type of cranberry saucedo you typically have? - Other (please specify)',
#        'Do you typically have gravy?',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %%
#number of people that celebrate thanksgiving
celebrate_column = data.iloc[:,1]
celebrate_column.value_counts()
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
#altering data to have only rows where respondants answered 'yes' to celebrating thanksgiving 
data = data[data.iloc[:,1] == 'Yes']
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
#Main dish people eat during thanksgiving 
main_dish_col = data['What is typically the main dish at your Thanksgiving dinner?']
main_dish_col.value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
# A function that returns the boolean value of weather or no the respondant ate a particular pie. 
def null_values(column):
    null = pd.isnull(data[column])
    return null

# %%
apple_null = null_values('Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple')
apple_null.value_counts()
# Out:
# False    514
# True     466
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple, dtype: int64

# %%
pumpkin_null = null_values('Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin')
pumpkin_null.value_counts()
# Out:
# False    729
# True     251
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin, dtype: int64

# %%
pecan_null = null_values('Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan')
pecan_null.value_counts()
# Out:
# True     638
# False    342
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan, dtype: int64

# %%
# Number of people that eat all three pies during thanksgiving
no_pies = apple_null & pumpkin_null & pecan_null
no_pies.value_counts()
# Out:
# False    876
# True     104
# dtype: int64

# %%
#A function that returns the first age from the range in the 'Age' column and converts the age into an integer
def extract_age(age):
    if pd.isnull(age):
        return None
    age = age.split(" ")[0]
    age = age.replace("+","")
    return int(age)

# %%
data['int_age'] = data['Age'].apply(extract_age)
data['int_age'].describe()
# Out:
# count    947.000000
# mean      40.089757
# std       15.352014
# min       18.000000
# 25%       30.000000
# 50%       45.000000
# 75%       60.000000
# max       60.000000
# Name: int_age, dtype: float64

# %% [markdown]
# # Findings

# %% [markdown]
# The age group is evenly distributed despite using the first number in the age string

# %%
def extract_income(income):
    if pd.isnull(income):
        return None
    income = income.split(" ")[0]
    if income == 'Prefer':
        return None
    income = income.replace('$' , '')
    income = income.replace(',' , '')
    return int(income)

# %%
data['int_income'] = data['How much total combined money did all members of your HOUSEHOLD earn last year?'].apply(extract_income)
data['int_income'].describe()
# Out:
# count       829.000000
# mean      75965.018094
# std       59068.636748
# min           0.000000
# 25%       25000.000000
# 50%       75000.000000
# 75%      100000.000000
# max      200000.000000
# Name: int_income, dtype: float64

# %%
data[data['int_income'] <150000]['How far will you travel for Thanksgiving?'].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %%
data[data['int_income']> 150000]['How far will you travel for Thanksgiving?'].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# # Findings

# %% [markdown]
# We can see that those with lower income are more inclined to travel for thanksgiving than those with higher income. This could because younger people with lower income may go home for thanksgiving, given their income

# %%
data.pivot_table(index = "Have you ever tried to meet up with hometown friends on Thanksgiving night?" ,
                 columns = 'Have you ever attended a "Friendsgiving?"', 
                 values = 'int_age')
# Out:
# Have you ever attended a "Friendsgiving?"                  No        Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  42.283702  37.010526
# Yes                                                 41.475410  33.976744

# %%
data.pivot_table(index = "Have you ever tried to meet up with hometown friends on Thanksgiving night?" ,
                 columns = 'Have you ever attended a "Friendsgiving?"', 
                 values = 'int_income')
# Out:
# Have you ever attended a "Friendsgiving?"                     No           Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  78914.549654  72894.736842
# Yes                                                 78750.000000  66019.736842

# %% [markdown]
# # Findings

# %% [markdown]
# The ages of those who responded 'yes' to attending "Friendsgiving" and "meet[ing] up with hometown friends for thanksgiving" are reletively young. They also show to have a lower salary than those who repsonded 'No' to both quesitions, confirming the above findings.

# %%
data.columns.get_loc('Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler')
# Out:
# 39

# %%
dessert_columns = data.loc[:,'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler' 
                           : 'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler']
dessert_columns.head()
# Out:
#   Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies  \
# 0                                                NaN
# ...

# %%
dessert_count = {}
for column in dessert_columns.columns:
    dessert_name = column.split(' ')[-1]
    dessert_count[dessert_name] = pd.notnull(dessert_columns[column]).value_counts()[True]

#renaming the names of dessert the function could not capture
dessert_count['Carrot cake'] = dessert_count.pop('cake')
dessert_count['Icecream'] = dessert_count.pop('cream')

dessert_count
# Out:
# {'cobbler': 103,
#  'Blondies': 16,
#  'Brownies': 128,
#  'Cheesecake': 191,
#  'Cookies': 204,
#  'Fudge': 43,
#  'Carrot cake': 72,
#  'Icecream': 266}

# %% [markdown]
# # Findings

# %% [markdown]
# Icecream is the most popular dessert choice for Thanksgiving

# %%
meal_columns = data.loc[:,'What is typically the main dish at your Thanksgiving dinner?':
    'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Other (please specify)']
meal_columns
# Out:
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# 5                                                Turkey
# 6                                                Turkey
# 7                                                Turkey
# 8                                                Turkey
# 9                                Other (please specify)
# 11                                               Turkey
# 12                                             Ham/Pork
# 13                                               Turkey
# 14                                               Turkey
# 15                                               Turkey
# 16                                            Turducken
# ...

# %%
meal_columns.duplicated().sum()
# Out:
# 16

# %%
duplicate_meals = meal_columns.loc[meal_columns.duplicated(keep=False),:]
duplicate_meals
# Out:
#      What is typically the main dish at your Thanksgiving dinner?  \
# 128                                              Turkey
# 129                                              Turkey
# 161                                              Turkey
# 204                                              Turkey
# 226                                              Turkey
# 234                                              Turkey
# 295                                              Turkey
# 306                                              Turkey
# 330                                              Turkey
# 364                                                 NaN
# 385                                              Turkey
# 396                                              Turkey
# 423                                              Turkey
# 533                                              Turkey
# 538                                              Turkey
# 593                                                 NaN
# ...
